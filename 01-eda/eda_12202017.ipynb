# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../00-preprocessing/otr_clean.csv')
df.head()
# Out:
#          date              neighborhood       assessor  ward  land_area  \
# 0  2015-06-29  American University Park  Parker Norman   3.0       7500
# 1  2013-07-15  American University Park  Parker Norman   3.0       6000
# 2  2011-12-27  American University Park  Parker Norman   3.0       5296
# 3  2010-07-07  American University Park  Parker Norman   3.0       6000
# 4  2017-11-27  American University Park  Parker Norman   3.0       5017
#
#          owner_name  sale_price sales_code    sales_type  land_2017  ...   \
# 0      Dan I Magder     1073000     MARKET  I - IMPROVED   526200.0  ...
# 1  Thomas J Leonard      880000     MARKET  I - IMPROVED   480570.0  ...
# 2   Jennifer Budoff      817000     MARKET  I - IMPROVED   494910.0  ...
# 3     Hyesook Chung      880000     MARKET  I - IMPROVED   505860.0  ...
# 4      John W Hanna     1040000     MARKET  I - IMPROVED   490110.0  ...
#
#    homestead_yes  homestead_senior  homestead_no  zip_code  state        city  \
# ...

# %%
temp = df.groupby(['year', 'qtr'])['use_code'].agg('count')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-ac5fb94dd712> in <module>()
# ----> 1 temp = df.groupby(['year', 'qtr'])['use_code'].agg('count')
#
# /anaconda/lib/python3.6/site-packages/pandas/core/base.py in __getitem__(self, key)
#     352         else:
#     353             if key not in self.obj:
# --> 354                 raise KeyError("Column not found: %s" % key)
#     355             return self._gotitem(key, ndim=1)
#     356
#
# KeyError: 'Column not found: use_code'

# %%
new = pd.DataFrame(temp)

# %%
new # there
# Out:
#           use_code
# year qtr
# 1990 1           1
#      2           4
#      3           3
#      4           4
# 1991 1           1
#      2           3
#      3           1
#      4           7
# 1992 1           4
#      2           5
#      3           6
#      4           2
# 1993 1           3
#      2           2
#      3           3
#      4           6
# 1994 1           3
#      2           1
#      3           7
#      4           4
# 1995 1           9
#      2           8
#      3           4
#      4           4
# 1996 1          11
#      2           9
#      3           4
#      4          12
# 1997 1          14
#      2         152
# ...            ...
# 2010 3         334
#      4         299
# 2011 1         326
#      2         381
#      3         376
#      4         352
# 2012 1         323
#      2         395
#      3         439
#      4         417
# 2013 1         393
#      2         565
#      3         563
#      4         513
# 2014 1         442
# ...

# %%
here, we can clearly see that there is an increase in home sales starting from 1990. whether that's a testament to bookkeeping, I don't know. 

now, this is an aggregate count, what I will ahve to do is break it out by neighborhood, and do some regression analysis to guage the trend.
